# %%
import numpy as np
import pandas as pd
df=pd.read_csv("C:/PROJECT/ML/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df=df.drop(['Id'],axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=30)

# %%
x_train
# Out:
# array([[5.1, 2.5, 3. , 1.1],
#        [6. , 2.9, 4.5, 1.5],
#        [6.5, 3. , 5.2, 2. ],
#        [5.1, 3.5, 1.4, 0.2],
#        [6.3, 2.5, 4.9, 1.5],
#        [5.6, 3. , 4.1, 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.6, 2.9, 3.6, 1.3],
#        [5.8, 4. , 1.2, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [6.3, 3.3, 6. , 2.5],
#        [6.4, 2.9, 4.3, 1.3],
#        [5.8, 2.7, 3.9, 1.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [7.7, 2.8, 6.7, 2. ],
#        [5.7, 3.8, 1.7, 0.3],
#        [7.4, 2.8, 6.1, 1.9],
#        [5.7, 2.8, 4.5, 1.3],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 2.3, 3.3, 1. ],
#        [7.1, 3. , 5.9, 2.1],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.8, 2.6, 4. , 1.2],
#        [5.7, 2.8, 4.1, 1.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.4, 3.9, 1.7, 0.4],
#        [6.1, 3. , 4.6, 1.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5. , 2. , 3.5, 1. ],
#        [6.5, 3. , 5.8, 2.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 3. , 5.2, 2.3],
#        [5.7, 3. , 4.2, 1.2],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.7, 3. , 5. , 1.7],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.8, 2.8, 5.1, 2.4],
#        [5.2, 2.7, 3.9, 1.4],
#        [6.7, 3.1, 4.4, 1.4],
#        [6. , 3.4, 4.5, 1.6],
#        [5.7, 4.4, 1.5, 0.4],
#        [7.7, 3. , 6.1, 2.3],
#        [5.7, 2.5, 5. , 2. ],
#        [4.8, 3.4, 1.9, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.3, 3.3, 4.7, 1.6],
#        [5. , 3.5, 1.3, 0.3],
#        [5. , 3.5, 1.6, 0.6],
#        [6.9, 3.1, 5.1, 2.3],
#        [7.2, 3. , 5.8, 1.6],
#        [6. , 3. , 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [5. , 3.2, 1.2, 0.2],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 2.6, 6.9, 2.3],
#        [6.8, 3.2, 5.9, 2.3],
#        [5. , 3.4, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [6.7, 3.1, 4.7, 1.5],
#        [5.6, 2.7, 4.2, 1.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5.4, 3. , 4.5, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [7.2, 3.2, 6. , 1.8],
#        [6.4, 3.2, 5.3, 2.3],
#        [7.9, 3.8, 6.4, 2. ],
#        [5.6, 2.5, 3.9, 1.1],
#        [6.6, 3. , 4.4, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [7.7, 3.8, 6.7, 2.2],
#        [6.9, 3.2, 5.7, 2.3],
#        [6.7, 3.1, 5.6, 2.4],
#        [5.4, 3.4, 1.7, 0.2],
#        [6.1, 2.8, 4.7, 1.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.9, 2.5, 4.5, 1.7],
#        [5.6, 2.8, 4.9, 2. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6.4, 2.8, 5.6, 2.1],
#        [5.5, 2.5, 4. , 1.3],
#        [6.1, 2.9, 4.7, 1.4],
#        [6.1, 3. , 4.9, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.2, 3.4, 1.4, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [6. , 2.2, 5. , 1.5],
#        [4.8, 3. , 1.4, 0.3],
#        [6.7, 3.3, 5.7, 2.1],
#        [5. , 3.4, 1.6, 0.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.3, 2.3, 4.4, 1.3],
#        [4.7, 3.2, 1.3, 0.2],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.1, 2.6, 5.6, 1.4],
#        [6.3, 2.8, 5.1, 1.5],
#        [7.6, 3. , 6.6, 2.1],
#        [6.8, 3. , 5.5, 2.1],
#        [5. , 3. , 1.6, 0.2],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.9, 3. , 5.1, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.9, 3.1, 4.9, 1.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [4.4, 2.9, 1.4, 0.2],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3.4, 1.6, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.5, 2.4, 3.7, 1. ],
#        [4.5, 2.3, 1.3, 0.3]])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[ 0.12477965, -2.03183983,  0.07276027, -0.33929248],
#        [ 0.36435657,  0.81155118,  0.87169654,  1.40181365],
#        [-0.47416266, -1.08404282,  0.30102778, -0.07143   ],
#        [ 0.96329887, -1.32099207,  1.09996405,  0.73215745],
#        [-1.31268188,  0.10070343, -1.29684477, -1.4107424 ],
#        [-0.23458574, -0.37319507,  0.18689402,  0.06250125],
#        [-0.9533165 ,  1.75934819, -1.29684477, -1.4107424 ],
#        [ 0.84351041, -0.37319507,  0.41516153,  0.06250125],
#        [ 1.32266425,  0.33765268,  0.47222841,  0.19643249],
#        [ 0.48414503, -1.32099207,  0.64342904,  0.86608869],
#        [-1.79183572, -0.13624582, -1.46804541, -1.4107424 ],
#        [ 0.48414503,  0.81155118,  0.9858303 ,  1.53574489],
#        [ 0.36435657, -2.03183983,  0.35809465,  0.33036373],
#        [-1.91162418, -0.13624582, -1.58217916, -1.54467364],
#        [ 0.12477965, -0.84709357,  0.70049591,  0.46429497],
#        [-1.31268188, -0.13624582, -1.41097853, -1.54467364],
#        [-0.9533165 ,  1.04850044, -1.41097853, -1.27681116],
#        [-0.47416266,  2.70714519, -1.41097853, -1.4107424 ],
#        [-1.07310496,  1.28544969, -1.41097853, -1.4107424 ],
#        [-1.19289342,  0.10070343, -1.35391165, -1.54467364],
#        [-0.47416266, -1.55794133, -0.04137349, -0.20536124],
#        [-1.5522588 ,  0.81155118, -1.41097853, -1.27681116],
#        [ 0.96329887,  0.57460193,  1.04289717,  1.66967613],
#        [ 0.48414503, -0.84709357,  0.58636216,  0.73215745],
#        [-0.3543742 , -0.13624582,  0.35809465,  0.33036373],
#        [ 1.08308733, -0.61014432,  0.52929528,  0.19643249],
#        [-0.59395112,  1.52239894, -1.35391165, -1.4107424 ],
#        [-1.19289342,  0.10070343, -1.35391165, -1.54467364],
#        [-0.9533165 ,  0.81155118, -1.35391165, -1.4107424 ],
#        [-0.23458574, -1.08404282, -0.21257412, -0.33929248]])

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
confusion=confusion_matrix(y_pred,y_test)
print(confusion)
score=accuracy_score(y_pred,y_test)
print(score)
# Out:
# [[13  0  0]
#  [ 0 10  0]
#  [ 0  1  6]]
# 0.9666666666666667

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion='entropy')
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor'], dtype=object)

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
tree.plot_tree(model)
# Out:
# [Text(0.375, 0.9166666666666666, 'x[3] <= -0.607\nentropy = 1.581\nsamples = 120\nvalue = [37, 39, 44]'),
#  Text(0.25, 0.75, 'entropy = 0.0\nsamples = 37\nvalue = [37, 0, 0]'),
#  Text(0.5, 0.75, 'x[2] <= 0.501\nentropy = 0.997\nsamples = 83\nvalue = [0, 39, 44]'),
#  Text(0.25, 0.5833333333333334, 'x[3] <= 0.531\nentropy = 0.183\nsamples = 36\nvalue = [0, 35, 1]'),
#  Text(0.125, 0.4166666666666667, 'entropy = 0.0\nsamples = 35\nvalue = [0, 35, 0]'),
#  Text(0.375, 0.4166666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.75, 0.5833333333333334, 'x[2] <= 0.672\nentropy = 0.42\nsamples = 47\nvalue = [0, 4, 43]'),
#  Text(0.625, 0.4166666666666667, 'x[0] <= 0.424\nentropy = 0.971\nsamples = 10\nvalue = [0, 4, 6]'),
#  Text(0.5, 0.25, 'x[1] <= 0.101\nentropy = 0.592\nsamples = 7\nvalue = [0, 1, 6]'),
#  Text(0.375, 0.08333333333333333, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6]'),
#  Text(0.625, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.75, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.875, 0.4166666666666667, 'entropy = 0.0\nsamples = 37\nvalue = [0, 0, 37]')]

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
tree.plot_tree(model,feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],class_names=['Iris-setosa','Iris-versicolor','Iris-virginica'],filled=True)
# Out:
# [Text(0.375, 0.9166666666666666, 'PetalWidthCm <= -0.607\nentropy = 1.581\nsamples = 120\nvalue = [37, 39, 44]\nclass = Iris-virginica'),
#  Text(0.25, 0.75, 'entropy = 0.0\nsamples = 37\nvalue = [37, 0, 0]\nclass = Iris-setosa'),
#  Text(0.5, 0.75, 'PetalLengthCm <= 0.501\nentropy = 0.997\nsamples = 83\nvalue = [0, 39, 44]\nclass = Iris-virginica'),
#  Text(0.25, 0.5833333333333334, 'PetalWidthCm <= 0.531\nentropy = 0.183\nsamples = 36\nvalue = [0, 35, 1]\nclass = Iris-versicolor'),
#  Text(0.125, 0.4166666666666667, 'entropy = 0.0\nsamples = 35\nvalue = [0, 35, 0]\nclass = Iris-versicolor'),
#  Text(0.375, 0.4166666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Iris-virginica'),
#  Text(0.75, 0.5833333333333334, 'PetalLengthCm <= 0.672\nentropy = 0.42\nsamples = 47\nvalue = [0, 4, 43]\nclass = Iris-virginica'),
#  Text(0.625, 0.4166666666666667, 'SepalLengthCm <= 0.424\nentropy = 0.971\nsamples = 10\nvalue = [0, 4, 6]\nclass = Iris-virginica'),
#  Text(0.5, 0.25, 'SepalWidthCm <= 0.101\nentropy = 0.592\nsamples = 7\nvalue = [0, 1, 6]\nclass = Iris-virginica'),
#  Text(0.375, 0.08333333333333333, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6]\nclass = Iris-virginica'),
#  Text(0.625, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Iris-versicolor'),
#  Text(0.75, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0]\nclass = Iris-versicolor'),
#  Text(0.875, 0.4166666666666667, 'entropy = 0.0\nsamples = 37\nvalue = [0, 0, 37]\nclass = Iris-virginica')]
